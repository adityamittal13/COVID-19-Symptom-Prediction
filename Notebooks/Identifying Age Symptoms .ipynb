# %%
import pandas as pd
df = pd.read_csv ('COVID19_line_list_data.csv')
df
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 0        1              NaN      1/20/2020         NaN
# 1        2              NaN      1/20/2020         NaN
# 2        3              NaN      1/21/2020         NaN
# 3        4              NaN      1/21/2020         NaN
# 4        5              NaN      1/21/2020         NaN
# ...    ...              ...            ...         ...
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary             location  \
# 0     First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1     First confirmed imported COVID-19 pneumonia pa...             Shanghai
# ...

# %%
esymptoms = pd.read_csv ('COVID19_line_list_data.csv')
esymptoms= esymptoms.dropna(subset = ['symptom'])
esymptoms= esymptoms.dropna(subset = ['age'])
esymptoms
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 194    195              NaN      1/27/2020         NaN
# 195    196              NaN      1/27/2020         NaN
# 196    197              NaN      1/27/2020         NaN
# 236    237              1.0      1/15/2020         NaN
# 240    241              5.0      1/28/2020         NaN
# ...    ...              ...            ...         ...
# 963    964             93.0      2/27/2020         NaN
# 992    993              1.0       02/02/20         NaN
# 995    996              1.0      1/29/2020         NaN
# 1006  1007             11.0      2/26/2020         NaN
# 1030  1031              1.0      1/31/2020         NaN
#
#                                                 summary          location  \
# 194   new recovered COVID-19 pneumonia patient in Hu...             Hubei
# 195   new recovered COVID-19 pneumonia patient in Hu...             Hubei
# 196   new recovered COVID-19 pneumonia patient in Sh...          Shandong
# ...

# %%
ages=esymptoms[['age']]
print(ages)
# Out:
#        age
# 194   28.0
# 195   51.0
# 196   37.0
# 236   35.0
# 240   45.0
# ...    ...
# 963   89.0
# 992   44.0
# 995   32.0
# 1006  22.0
# 1030  25.0
#
# [265 rows x 1 columns]

# %%
symptoms= esymptoms[['symptom']]
print(symptoms)
# Out:
#                                     symptom
# 194   feaver, cough, difficult in breathing
# 195   feaver, cough, difficult in breathing
# 196                                   fever
# 236                                   fever
# 240                                   fever
# ...                                     ...
# 963                                   cough
# 992               fever, cough, sore throat
# 995                                   fever
# 1006                     sore throat, fever
# 1030                                  cough
#
# [265 rows x 1 columns]

# %%
age_sympt=pd.concat([ages, symptoms], axis=1)
age_sympt
# Out:
#        age                                symptom
# 194   28.0  feaver, cough, difficult in breathing
# 195   51.0  feaver, cough, difficult in breathing
# 196   37.0                                  fever
# 236   35.0                                  fever
# 240   45.0                                  fever
# ...    ...                                    ...
# 963   89.0                                  cough
# 992   44.0              fever, cough, sore throat
# 995   32.0                                  fever
# 1006  22.0                     sore throat, fever
# 1030  25.0                                  cough
#
# [265 rows x 2 columns]

# %%
age_sympt.to_csv('age_sympt.csv',index=False)

# %%
pd.read_csv ('age_sympt.csv')
# Out:
#       age                                symptom
# 0    28.0  feaver, cough, difficult in breathing
# 1    51.0  feaver, cough, difficult in breathing
# 2    37.0                                  fever
# 3    35.0                                  fever
# 4    45.0                                  fever
# ..    ...                                    ...
# 260  89.0                                  cough
# 261  44.0              fever, cough, sore throat
# 262  32.0                                  fever
# 263  22.0                     sore throat, fever
# 264  25.0                                  cough
#
# [265 rows x 2 columns]

# %%
age_sympt
# Out:
#        age                                symptom
# 194   28.0  feaver, cough, difficult in breathing
# 195   51.0  feaver, cough, difficult in breathing
# 196   37.0                                  fever
# 236   35.0                                  fever
# 240   45.0                                  fever
# ...    ...                                    ...
# 963   89.0                                  cough
# 992   44.0              fever, cough, sore throat
# 995   32.0                                  fever
# 1006  22.0                     sore throat, fever
# 1030  25.0                                  cough
#
# [265 rows x 2 columns]

# %%
age_sympt=age_sympt.sort_values('age')
age_sympt
# Out:
#       age                        symptom
# 430   4.0              fever, cough, flu
# 418   5.0                   fever, cough
# 416   5.0                   fever, cough
# 315   5.0                          fever
# 339  15.0    fever, sore throat, malaise
# ..    ...                            ...
# 262  85.0                        fatigue
# 395  85.0  fever, cough, sputum, dyspnea
# 291  85.0               fever, pneumonia
# 421  85.0                   cough, fever
# 963  89.0                          cough
#
# [265 rows x 2 columns]

# %%
age_sympt.to_csv('age_sympt.csv',index=False)

# %%
import pandas as pd

age_sympt = age_sympt.reset_index(drop = True)
age_sympt
# Out:
#       age                        symptom
# 0     4.0              fever, cough, flu
# 1     5.0                   fever, cough
# 2     5.0                   fever, cough
# 3     5.0                          fever
# 4    15.0    fever, sore throat, malaise
# ..    ...                            ...
# 260  85.0                        fatigue
# 261  85.0  fever, cough, sputum, dyspnea
# 262  85.0               fever, pneumonia
# 263  85.0                   cough, fever
# 264  89.0                          cough
#
# [265 rows x 2 columns]

# %%
dic = {'0-17': {'symptom_names':[], 'counter_values':[]}, 
       '18-49':{'symptom_names':[], 'counter_values':[]}, 
       '50-64':{'symptom_names':[], 'counter_values':[]},
       '65+':{'symptom_names':[], 'counter_values':[]}}
for index in age_sympt.index:
    age = age_sympt['age'][index]
    age_symptoms = age_sympt['symptom'][index].split(', ')
    if (age >= 0 and age <= 17):
        for ind in age_symptoms:
            if (ind in dic['0-17']['symptom_names']):
                dic['0-17']['counter_values'][dic['0-17']['symptom_names'].index(ind)] += 1
            else:
                dic['0-17']['counter_values'].append(1)
                dic['0-17']['symptom_names'].append(ind)
    if (age >= 18 and age <= 49):
        for ind in age_symptoms:
            if (ind in dic['18-49']['symptom_names']):
                dic['18-49']['counter_values'][dic['18-49']['symptom_names'].index(ind)] += 1
            else:
                dic['18-49']['counter_values'].append(1)
                dic['18-49']['symptom_names'].append(ind)
    if (age >= 50 and age <= 64):
        for ind in age_symptoms:
            if (ind in dic['50-64']['symptom_names']):
                dic['50-64']['counter_values'][dic['50-64']['symptom_names'].index(ind)] += 1
            else:
                dic['50-64']['counter_values'].append(1)
                dic['50-64']['symptom_names'].append(ind)
    else:
        for ind in age_symptoms:
            if (ind in dic['65+']['symptom_names']):
                dic['65+']['counter_values'][dic['65+']['symptom_names'].index(ind)] += 1
            else:
                dic['65+']['counter_values'].append(1)
                dic['65+']['symptom_names'].append(ind)
    
print(dic['0-17'])
for ind in list(dic.keys()):
    dic[ind] = pd.DataFrame(data = dic[ind])

dic['0-17'] = dic['0-17'].sort_values('counter_values', ascending=False)
dic['18-49'] = dic['18-49'].sort_values('counter_values', ascending=False)
dic['50-64'] = dic['50-64'].sort_values('counter_values', ascending=False)
dic['65+'] = dic['65+'].sort_values('counter_values', ascending=False)
dic['18-49']
# Out:
# {'symptom_names': ['fever', 'cough', 'flu', 'sore throat', 'malaise', 'runny nose'], 'counter_values': [5, 3, 1, 1, 1, 1]}
#              symptom_names  counter_values
# 0                    fever              67
# 2                    cough              40
# 1              sore throat              15
# 6                 headache               5
# 11                 malaise               5
# 9                 diarrhea               5
# 16              runny nose               5
# 4               joint pain               5
# 3                   chills               5
# 8                 vomiting               4
# 25             muscle pain               3
# 28                 fatigue               2
# 14              chest pain               2
# 23       throat discomfort               2
# 7                   nausea               1
# 22            itchy throat               1
# 30     shortness of breath               1
# 29     physical discomfort               1
# ...

# %%
dic['0-17'].to_csv('0-17.csv')
dic['18-49'].to_csv('18-49.csv')
dic['50-64'].to_csv('50-64.csv')
dic['65+'].to_csv('65+.csv')

# %%
from datetime import date

df_symptoms = df.dropna(subset = ['age', 'hosp_visit_date', 'exposure_start'])

#clustering algorithm based on how long it takes to go to the hospital after first symptom onset versus the age

df_symptoms = df_symptoms[['age', 'hosp_visit_date', 'exposure_start']]
df_symptoms = df_symptoms.reset_index(drop = True)
df_symptoms
#year month day
dictionary = {'age':[], 'numdays':[]}
for index in df_symptoms.index:
    hosp_date = str(df_symptoms['hosp_visit_date'][index]).split("/")
    exposure_date = str(df_symptoms['exposure_start'][index]).split("/")
    if (hosp_date[2] == "20"):
        hosp_date[2] = "2020"
    if (exposure_date[2] == "20"):
        exposure_date[2] = "2020"
    f_date = date(int(hosp_date[2]), int(hosp_date[0]), int(hosp_date[1]))
    l_date = date(int(exposure_date[2]), int(exposure_date[0]) , int(exposure_date[1]))
    delta = l_date - f_date
    dictionary['numdays'].append(abs(delta.days))
    dictionary['age'].append(df_symptoms['age'][index])

df_symptoms_new = pd.DataFrame(data = dictionary)
df_symptoms_new
# Out:
#      age  numdays
# 0   66.0       13
# 1   37.0       10
# 2   39.0       11
# 3   56.0       12
# 4   18.0        8
# ..   ...      ...
# 57  37.0       14
# 58  68.0       28
# 59  21.0       31
# 60  16.0       31
# 61  36.0       12
#
# [62 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df_symptoms_new['age'], df_symptoms_new['numdays'])

# %%
#incubation period - time till you see the first symtoms
#graph above - gives you teh time from first symptoms to hospitalization
#Elbow Curve
from sklearn.cluster import KMeans

clusters = range(1, 20)
kmeans_elbow = [KMeans(n_clusters=i) for i in clusters]
score = [kmeans_elbow[i].fit(df_symptoms_new).score(df_symptoms_new) for i in range(len(kmeans_elbow))]
plt.plot(clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
#Adding to Dataframe
df_symptoms_new["cluster_label"] = kmeans_elbow[5].fit(df_symptoms_new).labels_

#Applying K-Means Clustering (4 clusters)
kmeans = KMeans(n_clusters=6).fit(df_symptoms_new)
centroids = kmeans.cluster_centers_

plt.scatter(df_symptoms_new['age'], df_symptoms_new['numdays'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()

# %%
df_symptoms_new.loc[df_symptoms_new['cluster_label'] == 0]

#for an age range (35-45) the time from symptom onset to severe symptoms is around 8 days
#for an age range (50-60) the time from symptom onset to severe symptoms is around 11 days
# Out:
#      age  numdays  cluster_label
# 3   56.0       12              0
# 7   50.0       12              0
# 17  58.0       15              0
# 22  50.0        9              0
# 31  55.0       12              0
# 32  55.0       13              0
# 33  55.0        6              0
# 36  48.0       11              0
# 41  51.0       14              0
# 43  50.0       12              0
# 47  56.0        9              0
# 53  55.0        4              0
# 54  52.0       14              0

# %%
df_symptoms_new.loc[df_symptoms_new['cluster_label'] == 0].mean()
# Out:
# age              53.153846
# numdays          11.000000
# cluster_label     0.000000
# dtype: float64

# %%
symptoms_list = []
mean = []
for i in range(6):
    symptoms_list.append(df_symptoms_new.loc[df_symptoms_new['cluster_label'] == i])
    mean.append(df_symptoms_new.loc[df_symptoms_new['cluster_label'] == i].mean()['age'])
    
print(mean)
# Out:
# [53.15384615384615, 27.76923076923077, 40.24, 69.0, 18.5, 47.0]

# %%
symptoms_list = []
mean_num = []
for i in range(6):
    symptoms_list.append(df_symptoms_new.loc[df_symptoms_new['cluster_label'] == i])
    mean_num.append(df_symptoms_new.loc[df_symptoms_new['cluster_label'] == i].mean()['numdays'])
    
print(mean)
# Out:
# [53.15384615384615, 27.76923076923077, 40.24, 69.0, 18.5, 47.0]

# %%
dictionary = {'age':mean[:4], 'num_days':mean_num[:4]}
new_df_1 = pd.DataFrame(data = dictionary)

# %%
plt.scatter(new_df_1['age'], new_df_1['num_days'])
